# %% [markdown]
# <a href="https://colab.research.google.com/github/huynhtuan0701/CS112.L11/blob/main/Bai_3_2_Thuc_nghiem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1. Cấu hình máy**
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ảnh chụp máy tính:
#
# ![120757740_397905161227161_8009854672960108328_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**2. Tìm hệ số x**

# %%
# !git clone https://github.com/huynhtuan0701/CS112.L11
# !ls CS112.L11/
# Out:
# Cloning into 'CS112.L11'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.
# Bai_3_2_Thuc_nghiem.ipynb  README.md  test.csv

# %%
# Import thư viện
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# Đọc dữ liệu
data = pd.read_csv('/content/CS112.L11/test.csv')
print(data)
data.columns = ['size', 'operations']

import matplotlib.pyplot as plt
plt.scatter(data['size'], data['operations'])
# Out:
#         n        t(n)
# 0     269      200363
# 1     295      240633
# 2     324      292454
# 3     356      348185
# 4     391      426456
# 5     430      517377
# 6     473      611393
# 7     520      749247
# 8     572      897392
# 9     629     1105592
# 10    691     1330395
# 11    760     1578192
# 12    836     1929080
# 13    919     2343066
# 14   1010     2807678
# 15   1111     3397371
# 16   1222     4132581
# 17   1344     4994411
# 18   1478     6046883
# 19   1625     7255727
# 20   1787     8822435
# 21   1965    10632629
# 22   2161    12837684
# 23   2377    15509553
# 24   2614    18813408
# 25   2875    22731297
# 26   3162    27526691
# 27   3478    33235851
# 28   3825    40344203
# 29   4207    48806622
# 30   4627    58822305
# 31   5089    71185782
# 32   5597    86224901
# 33   6156   104562410
# 34   6771   126033377
# 35   7448   151997954
# 36   8192   184905581
# 37   9011   222852698
# 38   9912   270104432
# 39  10903   326830038
# 40  11993   395776454
# 41  13192   479301939
# 42  14511   578896592
# 43  15962   701626214
# 44  17558   848524889
# 45  19313  1026325181
# 46  21244  1242360123
# 47  23368  1501417029
# 48  25704  1816079321
# 49  28274  2200093853
# 50  31101  2660052551
# 51  34211  3217981688
# 52  37632  3893701232
# 53  41395  4718853204
# 54  45534  5705742971

# %% [markdown]
# ##f(n) = log2(n)

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = np.log2(X_)

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [3.84630858e+08]

# %% [markdown]
# # f(n) = sqrt(n)

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = np.sqrt(X_)

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [18891064.03543201]

# %% [markdown]
# # f(n) = n

# %%
X_ = data['size'].values.reshape(-1,1)

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [100481.25101391]

# %% [markdown]
# # f(n) = nlog2(n)

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = X_*np.log2(X_)

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [6668.50387966]

# %% [markdown]
# # f(n) = n**2

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = X_**2

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [2.75153969]

# %% [markdown]
# # f(n) = n**3

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = X_**3

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [6.69099733e-05]

# %% [markdown]
# # f(n) = 2**n

# %%
X_ = data['size'].values.reshape(-1,1)
X_ = 2**X_

# %%
regr = LinearRegression()

regr.fit(X_, data['operations'])
print(regr.coef_)
# Out:
# [0.]
